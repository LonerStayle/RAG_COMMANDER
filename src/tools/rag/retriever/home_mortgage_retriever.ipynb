# %%
import os, sys
from pathlib import Path

src_path = Path(os.getcwd()).resolve().parents[1]  
sys.path.append(str(src_path))
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# with open("/Users/seobi/PythonProjects/RAG_Commander/src/data/economic_metrics/대출금리_10년_데이터 - 최종.csv", "r", encoding="utf-8-sig") as f:
#     content = f.read()

# with open("/Users/seobi/PythonProjects/RAG_Commander/src/data/economic_metrics/대출금리_10년_데이터 - 최종.csv", "w", encoding="utf-8") as f:
#     f.write(content)

# %%
from tools.rag.retriever.home_mortgage_retriever import home_mortgage_retrieve
result = home_mortgage_retrieve()

# %%
result
# Out:
# [' 2025-08-01\n대출평균(연%): 4.06\n가계대출(연%): 4.17\n주택담보대출(연%): 3.96',
#  ' 2025-07-01\n대출평균(연%): 4.06\n가계대출(연%): 4.2\n주택담보대출(연%): 3.96',
#  ' 2025-06-01\n대출평균(연%): 4.09\n가계대출(연%): 4.21\n주택담보대출(연%): 3.93',
#  ' 2025-05-01\n대출평균(연%): 4.17\n가계대출(연%): 4.26\n주택담보대출(연%): 3.87',
#  ' 2025-04-01\n대출평균(연%): 4.19\n가계대출(연%): 4.36\n주택담보대출(연%): 3.98',
#  ' 2025-03-01\n대출평균(연%): 4.36\n가계대출(연%): 4.51\n주택담보대출(연%): 4.17',
#  ' 2025-02-01\n대출평균(연%): 4.46\n가계대출(연%): 4.52\n주택담보대출(연%): 4.23',
#  ' 2025-01-01\n대출평균(연%): 4.53\n가계대출(연%): 4.65\n주택담보대출(연%): 4.27',
#  ' 2024-12-01\n대출평균(연%): 4.64\n가계대출(연%): 4.72\n주택담보대출(연%): 4.25',
#  ' 2024-11-01\n대출평균(연%): 4.76\n가계대출(연%): 4.79\n주택담보대출(연%): 4.3',
#  ' 2024-10-01\n대출평균(연%): 4.67\n가계대출(연%): 4.55\n주택담보대출(연%): 4.05',
#  ' 2024-09-01\n대출평균(연%): 4.62\n가계대출(연%): 4.23\n주택담보대출(연%): 3.74',
#  ' 2024-08-01\n대출평균(연%): 4.48\n가계대출(연%): 4.08\n주택담보대출(연%): 3.51',
#  ' 2024-07-01\n대출평균(연%): 4.55\n가계대출(연%): 4.06\n주택담보대출(연%): 3.5',
# ...
