# %%
import os, sys
from pathlib import Path

src_path = Path(os.getcwd()).resolve().parents[1]  
sys.path.append(str(src_path))

# %%
from tools.send_gmail import send_markdown_as_html
# immortal0900@gmail.com
send_markdown_as_html(
    md_content="test",
    to="dlwlstjq410@gmail.com",
    title="[RAG Commander] 보고서 테스트"
)
# Out:
# ♻️  Gmail token 갱신 완료
# 💾 토큰 저장 완료 → /Users/seobi/PythonProjects/RAG_Commander/token.json
# ✅ HTML 본문 메일 전송 완료! ID: 19a44754c209d575
