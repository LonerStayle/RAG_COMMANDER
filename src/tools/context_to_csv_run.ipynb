# %%
import os, sys
from pathlib import Path

src_path = Path(os.getcwd()).resolve().parents[1]  
sys.path.append(str(src_path))

# %%
from tools.context_to_csv import upload_test
import pandas as pd
df = pd.read_csv("/Users/seobi/PythonProjects/RAG_Commander/src/data/supply_demand/서울시_구별_10년_월별_주택공급.csv")
upload_test(df)
# Out:
# 'https://drive.google.com/uc?id=1DcHqHReDJcIYiqamyBDfAalBXvprbZwH&export=download'
