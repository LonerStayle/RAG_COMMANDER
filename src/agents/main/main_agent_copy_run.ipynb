# %%
from agents.main.main_agent_copy import graph_builder
from utils.muck import muck_main_state
graph = graph_builder.compile()
invoke = await graph.ainvoke(muck_main_state)
# Out:
# ⚠️ 폰트 파일을 찾지 못했습니다. (한글 □ 가능) → /Users/seobi/PythonProjects/RAG_Commander/assets/fonts/NotoSansKR-Regular.ttf
# 📄 PDF 변환 완료 → /Users/seobi/PythonProjects/RAG_Commander/서울 송파구 석촌동
#  84타입, 120세대 사업 보고서.pdf
# 📎 첨부 완료: 서울 송파구 석촌동
#  84타입, 120세대 사업 보고서.pdf (application/pdf)
# ✅ 메일 전송 완료: 서울 송파구 석촌동
#  84타입, 120세대 사업 보고서 (ID: 19a5df170b95b5bc)
# ⚠️ 폰트 파일을 찾지 못했습니다. (한글 □ 가능) → /Users/seobi/PythonProjects/RAG_Commander/assets/fonts/NotoSansKR-Regular.ttf
# 📄 PDF 변환 완료 → /Users/seobi/PythonProjects/RAG_Commander/서울 송파구 석촌동
#  84타입, 120세대 사업 보고서 - 데이터 출처.pdf
# 📎 첨부 완료: 서울 송파구 석촌동
#  84타입, 120세대 사업 보고서 - 데이터 출처.pdf (application/pdf)
# ✅ 메일 전송 완료: 서울 송파구 석촌동
#  84타입, 120세대 사업 보고서 - 데이터 출처 (ID: 19a5df178a6295bc)
