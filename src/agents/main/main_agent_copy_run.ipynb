# %%
from agents.main.main_agent_copy import graph_builder
from utils.muck import muck_main_state
graph = graph_builder.compile()
invoke = await graph.ainvoke(muck_main_state)
# Out:
# c:\PythonProject\RAG_COMMANDER\.venv\Lib\site-packages\weasyprint\pdf\fonts.py:142: UserWarning: 'instantiateVariableFont' is deprecated; use fontTools.varLib.instancer.instantiateVariableFont instead for either full or partial instancing
#   ttfont = instantiateVariableFont(ttfont, self.variations)
# 📄 PDF 생성 완료: C:\PythonProject\RAG_COMMANDER\output\서울시 송파구 신천동 84 2275세대 사업보고서 작성_최종보고서.pdf
# 📄 PDF 생성 완료: C:\PythonProject\RAG_COMMANDER\output\서울시 송파구 신천동 84 2275세대 사업보고서 작성__데이터출처모음.pdf
# ✅ 메일 전송 완료 → dlwlstjq410@gmail.com (ID: 19a6b8edd2d13428)
