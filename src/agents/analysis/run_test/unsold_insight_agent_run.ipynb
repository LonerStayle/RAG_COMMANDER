# %%
from agents.analysis.unsold_insight_agent import unsold_insight_graph
invoke = unsold_insight_graph.invoke({
    "start_input": {
        "target_area": "서울 송파구 석촌동"
    }
})
# Out:
# 2025-11-02 22:12:08,730 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-02 22:12:35,011 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
mmd = unsold_insight_graph.get_graph().draw_mermaid()
print(mmd)
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	unsold_unit(unsold_unit)
# 	analysis_setting(analysis_setting)
# 	tools(tools)
# 	agent(agent)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> unsold_unit;
# 	agent -.-> __end__;
# 	agent -.-> tools;
# 	analysis_setting --> agent;
# 	tools --> agent;
# 	unsold_unit --> analysis_setting;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
print(invoke['unsold_insight_output'])
# Out:
# # 서울 송파구 석촌동 미분양 현황 시계열 정량 데이터
#
# ## 1. 월별 미분양 주택 수(2017.08~2025.08)
#
# | 연도 | 월  | 미분양(호) |
# |------|-----|-----------|
# | 2017 | 8   | 8         |
# | 2017 | 9   | 8         |
# | 2017 | 10  | 8         |
# | 2017 | 11  | 8         |
# | 2017 | 12  | 8         |
# | 2018 | 1   | 8         |
# | 2018 | 2   | 8         |
# | 2018 | 3   | 8         |
# | 2018 | 4   | 8         |
# | 2018 | 5   | 8         |
# | 2018 | 6   | 8         |
# | 2018 | 7   | 8         |
# | 2018 | 8   | 8         |
# | 2018 | 9   | 8         |
# | 2018 | 10  | 8         |
# | 2018 | 11  | 8         |
# | 2018 | 12  | 8         |
# | 2019 | 1   | 8         |
# | 2019 | 2   | 8         |
# | 2019 | 3   | 8         |
# | 2019 | 4   | 8         |
# | 2019 | 5   | 8         |
# | 2019 | 6   | 8         |
# | 2019 | 7   | 8         |
# | 2019 | 8   | 8         |
# | 2019 | 9   | 7         |
# | 2019 | 10  | 7         |
# | 2019 | 11  | 7         |
# | 2019 | 12  | 7         |
# | 2020 | 1   | 7         |
# ...
