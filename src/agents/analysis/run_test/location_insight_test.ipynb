# %%
import json

with open('src/agents/analysis/run_test/location_insight_agent.ipynb', 'r', encoding='utf-8') as f:
    notebook = json.load(f)

notebook['metadata']['kernelspec']['display_name'] = 'RAG_Commander'

with open('src/agents/analysis/run_test/location_insight_agent.ipynb', 'w', encoding='utf-8') as f:
    json.dump(notebook, f, ensure_ascii=False, indent=1)

print('커널 설정을 RAG_Commander로 변경했습니다.')
