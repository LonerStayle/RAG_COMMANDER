# %%
from dotenv import load_dotenv
from langchain_teddynote import logging

logging.langsmith("allforone")

# %%
from agents.analysis.location_insight_agent import location_insight_graph

invoke = await location_insight_graph.ainvoke(
    {
        "start_input": {
            "target_area": "서울 강남구 역삼동",
            "total_units": "1000세대",
            "main_type": "84제곱미터",
        }
    }
)

# %%
print(invoke)

# %%
output = invoke["location_insight_output"]

result_json = output["result"]

print("=" * 50)
print("📊 최종 분석 결과")
print("=" * 50)
print(result_json)
# Out:
# ==================================================
# 📊 최종 분석 결과
# ==================================================
# {
#   "입지정보": {
#     "주소": "서울 강남구 역삼동",
#     "좌표": {
#       "longitude": 127.03306536185,
#       "latitude": 37.4953666908087
#     },
#     "교육환경": {
#       "학교": [
#         {
#           "이름": "서울역삼초등학교",
#           "주소": "서울 강남구 강남대로66길 21",
#           "거리(미터)": 247
#         },
#         {
#           "이름": "서울서이초등학교",
#           "주소": "서울 서초구 서운로 35",
#           "거리(미터)": 751
#         },
#         {
#           "이름": "서운중학교",
#           "주소": "서울 서초구 서운로 115",
#           "거리(미터)": 761
#         }
#       ],
#       "학원": [
#         {
#           "이름": "강남대성학원",
#           "주소": "서울 강남구 테헤란로4길 39",
#           "거리(미터)": 196
#         },
#         {
#           "이름": "김영편입학원 강남단과캠퍼스",
#           "주소": "서울 강남구 강남대로78길 8",
#           "거리(미터)": 274
#         },
#         {
#           "이름": "시사일본어학원 강남캠퍼스",
#           "주소": "서울 강남구 테헤란로4길 28",
#           "거리(미터)": 292
#         }
#       ]
#     },
#     "교통여건": [
#       {
#         "이름": "강남역 신분당선",
#         "주소": "서울 강남구 강남대로 지하 396",
#         "거리(미터)": 459
#       },
#       {
#         "이름": "강남역 2호선",
#         "주소": "서울 강남구 강남대로 지하 396",
#         "거리(미터)": 540
#       },
#       {
#         "이름": "역삼역 2호선",
#         "주소": "서울 강남구 테헤란로 지하 156",
#         "거리(미터)": 661
#       }
#     ],
#     "편의여건": {
#       "대형마트": [
#         {
#           "이름": "GS더프레시 역삼중앙점",
#           "주소": "서울 강남구 논현로79길 66",
#           "거리(미터)": 98
#         },
#         {
#           "이름": "롯데프레시&델리 역삼3점",
#           "주소": "서울 강남구 역삼로 153",
#           "거리(미터)": 261
#         },
#         {
#           "이름": "롯데슈퍼 강남역가맹점",
#           "주소": "서울 강남구 강남대로84길 23",
#           "거리(미터)": 295
#         }
#       ],
#       "병원": [
#         {
#           "이름": "눈에미소안과의원",
#           "주소": "서울 강남구 강남대로 364",
#           "거리(미터)": 334
#         },
#         {
#           "이름": "원치과의원",
#           "주소": "서울 강남구 테헤란로10길 7",
#           "거리(미터)": 364
#         },
#         {
#           "이름": "오브제성형외과의원",
#           "주소": "서울 강남구 테헤란로4길 5",
#           "거리(미터)": 392
#         }
#       ]
#     },
#     "자연환경": [
#       {
#         "이름": "역삼무궁화공원",
#         "주소": "서울 강남구 역삼동 830-23",
#         "거리(미터)": 163
#       },
#       {
#         "이름": "역삼까치공원",
#         "주소": "서울 강남구 역삼동 824-10",
#         "거리(미터)": 293
#       },
#       {
#         "이름": "역삼개나리공원",
#         "주소": "서울 강남구 논현로79길 24",
#         "거리(미터)": 380
#       }
#     ],
#     "미래가치": [
#       {
#         "이름": "서초무지개아파트주택재건축정비사업조합",
#         "주소": "서울 서초구 효령로74길 4",
#         "거리(미터)": 1023
#       },
#       {
#         "이름": "서초삼호1차아파트 주택재건축정비사업조합",
#         "주소": "서울 서초구 서운로 207",
#         "거리(미터)": 1211
#       },
#       {
#         "이름": "대성재건축 (예정)",
#         "주소": "서울 강남구 논현로113길 8",
#         "거리(미터)": 1466
#       }
#     ]
#   },
#   "주변호재": [
#     {
#       "name": "영동대로 복합환승센터 및 GBC(글로벌비즈니스센터) 개발",
#       "location": "삼성역~봉은사역 일대",
#       "description": "GTX-A/C, 위례신사선 등 5개 철도노선이 통합된 복합환승센터와 현대차그룹의 GBC가 들어서는 대규모 개발 사업. 국제교류복합지구의 핵심으로, 완공 시 교통, 문화, 비즈니스의 중심지로 부상.",
#       "status": "공사 중, 복합환승센터는 2028년 4월 1차 완공 예정, GBC는 2030년 준공 목표(2025년 기준 40% 진행)"
#     },
#     {
#       "name": "수도권 광역급행철도 GTX-A/C 노선 삼성역 개통",
#       "location": "삼성역",
#       "description": "수도권 전역을 30분대로 연결하는 GTX-A와 C노선이 삼성역에 정차. 수도권 외곽 및 주요 도심으로의 접근성이 획기적으로 개선되어 광역 교통의 허브가 될 전망.",
#       "status": "공사 중, 삼성역 GTX-A/C는 2028년 완공 목표(2025년 기준 공정률 30% 내외)"
#     },
#     {
#       "name": "경부고속도로 지하화 사업 (한남IC~양재IC 구간)",
#       "location": "한남IC ~ 양재IC",
#       "description": "상습 정체 구간인 경부고속도로 서울 구간을 지하화하고, 지상에는 대규모 공원 및 복합문화공간을 조성하는 장기 프로젝트. 지역 단절 해소 및 주거환경 개선 효과 기대.",
#       "status": "계획 및 추진 중, 2029년 준공 목표(2025년 하반기 민자적격성 심사 결과에 따라 일정 확정 예정)"
#     }
#   ],
#   "해당지역 정보": {
#     "특징": [
#       "대한민국 대표 부촌으로 높은 구매력과 자산 가치를 보유한 수요층 다수 포진",
#       "강남 8학군 등 우수한 교육 환경으로 학령기 자녀를 둔 3040세대 선호도 높음",
#       "테헤란로 중심의 GBD(강남업무지구) 접근성으로 직주근접을 원하는 고소득 직장인 수요 풍부",
#       "안정적인 자산 증식 및 투자를 목적으로 하는 투자 수요가 실거주 수요와 함께 공존",
#       "신축 아파트, 특히 국민평형인 84㎡ 타입에 대한 희소성 및 대기 수요가 높아 프리미엄 기대"
#     ],
#     "주요타입": "84제곱미터",
#     "전체세대수": 1000,
#     "일시": "2025-11-05"
#   }
# }

# %%
print("=" * 50)
print("🔍 Gemini 검색 결과")
print("=" * 50)
print(output["gemini_search"])
# Out:
# ==================================================
# 🔍 Gemini 검색 결과
# ==================================================
# ```json
# {
#   "해당지역 특징": [
#     "대한민국 대표 부촌으로 높은 구매력과 자산 가치를 보유한 수요층 다수 포진",
#     "강남 8학군 등 우수한 교육 환경으로 학령기 자녀를 둔 3040세대 선호도 높음",
#     "테헤란로 중심의 GBD(강남업무지구) 접근성으로 직주근접을 원하는 고소득 직장인 수요 풍부",
#     "안정적인 자산 증식 및 투자를 목적으로 하는 투자 수요가 실거주 수요와 함께 공존",
#     "신축 아파트, 특히 국민평형인 84㎡ 타입에 대한 희소성 및 대기 수요가 높아 프리미엄 기대"
#   ],
#   "주변호재": [
#     {
#       "name": "영동대로 복합환승센터 및 GBC(글로벌비즈니스센터) 개발",
#       "location": "삼성역~봉은사역 일대",
#       "description": "GTX-A/C, 위례신사선 등 5개 철도노선이 통합된 복합환승센터와 현대차그룹의 GBC가 들어서는 대규모 개발 사업. 국제교류복합지구의 핵심으로, 완공 시 교통, 문화, 비즈니스의 중심지로 부상.",
#       "status": "공사 중, 2028년 이후 순차적 완공 예정"
#     },
#     {
#       "name": "수도권 광역급행철도 GTX-A/C 노선 삼성역 개통",
#       "location": "삼성역",
#       "description": "수도권 전역을 30분대로 연결하는 GTX-A와 C노선이 삼성역에 정차. 수도권 외곽 및 주요 도심으로의 접근성이 획기적으로 개선되어 광역 교통의 허브가 될 전망.",
#       "status": "공사 중, 삼성역은 복합환승센터와 연계하여 2028년 개통 목표"
#     },
#     {
#       "name": "경부고속도로 지하화 사업 (한남IC~양재IC 구간)",
#       "location": "한남IC ~ 양재IC",
#       "description": "상습 정체 구간인 경부고속도로 서울 구간을 지하화하고, 지상에는 대규모 공원 및 복합문화공간을 조성하는 장기 프로젝트. 지역 단절 해소 및 주거환경 개선 효과 기대.",
#       "status": "계획 및 추진 중"
#     }
#   ]
# }
# ```

# %%
print("=" * 50)
print("📍 카카오 API 위치 정보")
print("=" * 50)
print(json.dumps(output["kakao_api_distance_context"], ensure_ascii=False, indent=2))

# %%
print("=" * 50)
print("🌐 Perplexity 검색 결과")
print("=" * 50)
print(output["perplexity_search"])
# Out:
# ==================================================
# 🌐 Perplexity 검색 결과
# ==================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 4
#       2 print("🌐 Perplexity 검색 결과")
#       3 print("=" * 50)
# ----> 4 print(output["perplexity_search"])
#
# KeyError: 'perplexity_search'
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
