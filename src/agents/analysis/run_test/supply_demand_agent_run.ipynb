# %%
from agents.analysis.supply_demand_agent import supply_demand_graph
invoke = await supply_demand_graph.ainvoke({
    "start_input": {
        "target_area": "서울 강남구 역삼동"
    }
})
# Out:
# 2025-11-01 23:41:04,952 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 23:41:04,973 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 10년이상 노후도 호출 질문 강남구
# 10년이상 노후도 호출 결과 {'result': [{'house_cnt': '4166', 'adm_cd': '11230', 'adm_nm': '강남구'}], 'errCd': 0, 'errMsg': 'Success', 'id': 'API_0306', 'trId': 'YzoJ_API_0306_1762008065148'}
# 2025-11-01 23:41:05,574 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 23:41:05,582 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 23:41:07,554 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 23:41:13,486 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
print(invoke['supply_demand_output'])
# Out:
# # 서울 강남구 역삼동 공급·수요 시계열 데이터 정리
#
# ## 1. 노후주택(10년 이상) 현황
# | 구분 | 2025년 11월 기준 |
# |---|---|
# | 10년 이상 노후주택 수 | 4,166호 |
#
# ---
#
# ## 2. 아파트 전세가/매매가 월별 시계열 (2020.01~2025.09, 단위: 천원/㎡)
#
# | 연월 | 전세가(평균) | 매매가(평균) |
# |---|---|---|
# | 2020-01 | 769,973 | 1,758,527 |
# | 2020-07 | 785,301 | 1,731,527 |
# | 2021-01 | 832,344 | 1,757,349 |
# | 2021-07 | 1,131,300 | 2,196,672 |
# | 2022-01 | 1,168,145 | 2,305,732 |
# | 2022-07 | 1,168,554 | 2,311,575 |
# | 2023-01 | 1,017,777 | 2,150,633 |
# | 2023-07 | 950,639 | 2,167,105 |
# | 2024-01 | 982,551 | 2,212,518 |
# | 2024-07 | 998,429 | 2,277,387 |
# | 2025-01 | 1,026,643 | 2,415,000 |
# | 2025-07 | 1,029,506 | 2,721,234 |
# | 2025-09 | 1,032,035 | 2,750,424 |
#
# ※ 전체 월별 데이터는 별도 시트 참고
#
# ---
#
# ## 3. 매매수급지수 (서울 강남지역 동남권, 2024.10)
# | 구분 | 2024년 10월 |
# |---|---|
# | 매매수급지수 | 101.12 |
#
# ---
#
# ## 4. 금리 및 주택담보대출금리 시계열
#
# ### (1) 한국 기준금리/미국 기준금리 (연, %)
# | 연월 | 한국 | 미국 |
# |---|---|---|
# | 2023-01 | 3.5 | 4.33 |
# ...

# %%
invoke
# Out:
# {'start_input': {'target_area': '서울 강남구 역삼동'},
# ...

# %%
# mermaid_code = supply_demand_graph.get_graph().draw_mermaid()
# open("supply_demand.mmd","w").write(mermaid_code)
