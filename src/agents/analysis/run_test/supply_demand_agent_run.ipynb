# %%
from agents.analysis.supply_demand_agent import supply_demand_graph
invoke = supply_demand_graph.invoke({
    "start_input": {
        "target_area": "서울특별시 강남구 역삼동"
    }
})
# Out:
# 2025-11-01 14:06:33,909 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 10년이상 노후도 호출 질문 강남구
# 10년이상 노후도 호출 결과 {'result': [{'house_cnt': '4166', 'adm_cd': '11230', 'adm_nm': '강남구'}], 'errCd': 0, 'errMsg': 'Success', 'id': 'API_0306', 'trId': 'uSWC_API_0306_1761973594115'}
# 2025-11-01 14:06:34,470 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 14:06:34,570 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 14:06:35,167 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 14:06:41,081 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-01 14:07:00,513 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print(invoke['supply_demand_output'])
# Out:
# # 서울특별시 강남구 역삼동 공급·수요 시계열 데이터 정리
#
# ## 1. 노후주택 현황
# | 구분 | 10년 이상 노후주택 수(2025년) |
# |------|-----------------------------|
# | 강남구 | 4,166호 |
#
# ---
#
# ## 2. 아파트 전세가/매매가 월별 시계열 (단위: 천원/㎡)
#
# | 연월      | 전세가 평균 | 매매가 평균 |
# |-----------|------------|-------------|
# | 2020-01   | 769,973    | 1,758,527   |
# | 2020-07   | 785,301    | 1,731,527   |
# | 2021-01   | 832,344    | 1,757,349   |
# | 2021-07   | 1,131,300  | 2,196,672   |
# | 2022-01   | 1,168,145  | 2,305,732   |
# | 2022-07   | 1,168,554  | 2,311,575   |
# | 2023-01   | 1,017,777  | 2,150,633   |
# | 2023-07   | 950,639    | 2,167,105   |
# | 2024-01   | 982,551    | 2,212,518   |
# | 2024-07   | 998,429    | 2,277,387   |
# | 2025-01   | 1,026,643  | 2,415,000   |
# | 2025-07   | 1,029,506  | 2,721,234   |
# | 2025-09   | 1,032,035  | 2,750,424   |
#
# ※ 월별 전체 데이터는 별도 시트 참고
#
# ---
#
# ## 3. 매매수급지수 (서울>강남지역>서남권)
#
# | 연월      | 매매수급지수 |
# |-----------|-------------|
# | 2024-10   | 101.90      |
#
# ---
#
# ## 4. 금리 시계열 (한국 기준금리/주택담보대출금리, 연%)
#
# | 연월      | 한국 기준금리 | 주담대 금리 |
# |-----------|--------------|-------------|
# | 2023-01   | 3.5          | 4.58        |
# | 2023-07   | 3.5          | 4.28        |
# | 2024-01   | 3.5          | 3.99        |
# | 2024-07   | 3.5          | 3.50        |
# | 2025-01   | 3.0          | 4.27        |
# | 2025-07   | 2.5          | 3.96        |
#
# ※ 주담대 금리는 월별 변동, 2023년~2025년 하락세
#
# ---
#
# ## 5. 1인당 GDP/GRDP (단위: 원)
#
# | 연도 | 대한민국 1인당 GDP | 강남구 1인당 GRDP |
# |------|-------------------|-------------------|
# | 2018 | 36,791,700        | 142,725,114       |
# | 2019 | 37,006,320        | 151,712,824       |
# | 2020 | 37,430,780        | 153,117,569       |
# | 2021 | 40,042,500        | 165,164,840       |
# | 2022 | 41,788,260        | 168,569,944       |
# | 2023 | 43,388,510        | -                 |
# | 2024 | 49,808,640        | -                 |
#
# ---
#
# ## 6. 매매 거래량 (동/호수, 강남구 전체)
#
# | 연월      | 거래량(호) |
# |-----------|-----------|
# | 2020-10   | 336       |
# | 2021-07   | 468       |
# | 2022-01   | 297       |
# | 2022-10   | 103       |
# | 2023-01   | 107       |
# | 2023-07   | 341       |
# | 2024-01   | 197       |
# | 2024-07   | 689       |
# | 2025-01   | 236       |
# | 2025-03   | 969       |
# | 2025-07   | 742       |
#
# ※ 월별 전체 데이터는 별도 시트 참고
#
# ---
#
# ## 7. 입주 예정 물량 (강남구, 2025~2027)
#
# | 입주예정월 | 주소(동)         | 주택명                | 세대수 | 사업유형 |
# |------------|------------------|-----------------------|--------|----------|
# | 2025-08    | 대치동 964       | 디에이치 대치 에델루이| 282    | 분양     |
# | 2025-11    | 청담동 134-18    | 청담 르엘             | 1,261  | 분양     |
# | 2025-12    | 논현동 150-4     | 학동역에스포레논현     | 41     | 분양     |
# | 2026-10    | 도곡동 540       | 래미안 레벤투스       | 308    | 분양     |
# | 2026-12    | 논현동 221-16    | 강남구논현동221-16    | 94     | 임대     |
# | 2026-12    | 도곡동 547-1     | 도곡동가로주택정비     | 82     | 분양     |
# | 2027-05    | 대치동 951       | 비취타운              | 95     | 분양     |
#
# ---
#
# ## 8. 요약 메시지(최종 보고서용)
#
# - 강남구 역삼동 인근은 10년 이상 노후주택 4,166호, 2020~2025년간 전세가·매매가 모두 상승세, 2023년 이후 거래량·입주물량 증가, 2024~2025년 금리 하락, 2025~2027년 대규모 신규 입주 예정, 1인당 GRDP 전국 대비 월등히 높음.
#
# ---
#
# ## 9. 리스크 및 참고
#
# - 2025~2027년 신규 입주물량 집중(특히 2025년 하반기~2026년), 단기적 공급 증가 가능성
# - 금리 하락세이나, 주택담보대출금리 변동성 주의
# - 매매수급지수 100 초과(2024년 10월 기준), 수요 우위 신호
# - 2023년~2024년 거래량 급증 구간 존재, 단기 변동성 유의
#
# ---
#
# **위 표와 시계열 데이터는 최종 보고서 작성 시 공급·수요, 가격, 거래, 금리, 경제력 등 주요 지표의 시계열적 변화와 현재 위치를 정량적으로 파악할 수 있도록 구성됨.**
