# %%
import os, sys
from pathlib import Path

src_path = Path(os.getcwd()).resolve().parents[1]  
sys.path.append(str(src_path))

# %%
from agents.analysis.policy_agent import policy_graph
invoke = policy_graph.invoke({
    "start_input": {
        "target_area": "서울특별시 강남구 역삼동"
    }
})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from agents.analysis.policy_agent import policy_graph
#       2 invoke = policy_graph.invoke({
#       3     "start_input": {
#       4         "target_area": "서울특별시 강남구 역삼동"
#       5     }
#       6 })
#
# File ~/PythonProjects/RAG_Commander/src/agents/analysis/__init__.py:1
# ----> 1 from .analysis_graph import analysis_graph
#       2 from .policy_agent import policy_graph
#       3 from .housing_faq_agent import housing_faq_graph
#
# File ~/PythonProjects/RAG_Commander/src/agents/analysis/analysis_graph.py:8
#       6 from agents.analysis.policy_agent import policy_graph
#       7 from agents.analysis.housing_faq_agent import housing_faq_graph
# ----> 8 from agents.analysis.location_insight_agent import location_insight_graph
# ...

# %%
print(invoke['policy_output'])
