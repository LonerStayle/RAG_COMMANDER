# %%
import os, sys
from pathlib import Path

src_path = Path(os.getcwd()).resolve().parents[1]  
sys.path.append(str(src_path))

# %%
from agents.renderer.renderer_agent import renderer_graph
from agents.renderer.test_prompt import final_report_dummy
invoke = renderer_graph.invoke({
    "start_input": {
        "target_area": "서울특별시 강남구 역삼동",
        "main_type":"84제곱미터",
        "total_units":"120",
        "email":"dlwlstjq410@gmail.com"
    },
    "final_report":final_report_dummy
})
# Out:
# PPTX saved: /Users/seobi/PythonProjects/RAG_Commander/src/agents/renderer/temp/78ea0fd041014a57979b72e3d26983a1.pptx
# 📎 첨부파일 추가 완료: 78ea0fd041014a57979b72e3d26983a1.pptx
# ✅ HTML 본문 메일 전송 완료! ID: 19a571f92ca424a8

# %%
renderer_graph
